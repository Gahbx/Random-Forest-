# %%
# biblioteca modelagem de dados
import pandas as pd
# biblioteca recursos matematicos
import numpy as np 
# biblioteca plotagem de dados
import seaborn as sns
import matplotlib.pyplot as plt
# biblioteca/funcao ignorar avvisos
from warnings import filterwarnings

# %%
# Plan1 = base dados
# Plan2= Novas Entradas

df = pd.read_excel('BaseDados_FlorestaDeDecisão.xlsx', 'Plan1')

# %%
# 1 nao usou 
# 2 = servico
# 3 = furto
df.head()
# Out:
#    Id Cliente  Idade  Preço Seguro    CEP  Serviço
# 0           1     69          3930  19005        3
# 1           2     27          3336  19027        1
# 2           3     49          3936  19001        3
# 3           4     60           157  19009        1
# 4           5     51          3998  19050        2

# %%
df.info
# Out:
# <bound method DataFrame.info of      Id Cliente  Idade  Preço Seguro    CEP  Serviço
# 0             1     69          3930  19005        3
# 1             2     27          3336  19027        1
# 2             3     49          3936  19001        3
# 3             4     60           157  19009        1
# 4             5     51          3998  19050        2
# ..          ...    ...           ...    ...      ...
# 495         496     24           389  19026        1
# 496         497     47           967  19022        1
# 497         498     58          1520  19019        2
# 498         499     72          3155  19029        3
# 499         500     54          3656  19034        3
#
# [500 rows x 5 columns]>

# %%
df.describe()
# Out:
#        Id Cliente       Idade  Preço Seguro           CEP     Serviço
# count  500.000000  500.000000    500.000000    500.000000  500.000000
# mean   250.500000   49.550000   1939.268000  19024.812000    1.904000
# std    144.481833   18.167984   1402.289601     15.079105    0.858054
# min      1.000000   18.000000    100.000000  19000.000000    1.000000
# 25%    125.750000   33.750000    612.000000  19011.000000    1.000000
# 50%    250.500000   51.000000   1667.500000  19025.000000    2.000000
# 75%    375.250000   65.000000   3329.500000  19038.000000    3.000000
# max    500.000000   80.000000   3998.000000  19050.000000    3.000000

# %%
sns.set(font_scale=1.5, rc={'figure.figsize':(20,20)})
eixo= df.hist(bins=20, color='blue')

# %%
plt.figure(figsize={10,5})
sns.boxplot(data=df , x='Serviço',y='Idade');

# %%
plt.figure(figsize={10,5})
sns.boxplot(data=df , x='Serviço',y='Preço Seguro');

# %%
plt.figure(figsize={10,5})
sns.boxplot(data=df , x='Serviço',y='CEP');

# %%
Caracteristicas = df.iloc[:, 1:4].values
Previsor= df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_teste, y_train, y_teste = train_test_split(
    Caracteristicas,
    Previsor,
    test_size=0.3,
    random_state=10
)
print(len(df))
print(len(x_train))
print(len(x_teste))
# Out:
# 500
# 350
# 150

# %%
from sklearn.ensemble import RandomForestClassifier

Algoritmo_floresta_aleatoria = RandomForestClassifier(n_estimators=500)

Algoritmo_floresta_aleatoria.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
Previsoes = Algoritmo_floresta_aleatoria.predict(x_teste)

from sklearn.metrics import confusion_matrix
Matriz_Confusao= confusion_matrix(y_teste, Previsoes)
print(Matriz_Confusao)

plt.figure(figsize=(10,5))
sns.heatmap(Matriz_Confusao, annot=True);
# Out:
# [[60  3  1]
#  [ 7 21  8]
#  [ 1  1 48]]

# %%
from sklearn.metrics import classification_report
report= classification_report(y_teste, Previsoes)
print (report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.94      0.91        64
#            2       0.84      0.58      0.69        36
#            3       0.84      0.96      0.90        50
#
#     accuracy                           0.86       150
#    macro avg       0.85      0.83      0.83       150
# weighted avg       0.86      0.86      0.85       150

# %%
NovasVendas_df= pd.read_excel('BaseDados_FlorestaDeDecisão.xlsx', 'Plan2')

# %%
NovasVendas_df.head()
# Out:
#    Id Cliente  Idade  Preço Seguro    CEP
# 0        1001     25           801  19001
# 1        1002     27          1090  19027
# 2        1003     45           364  19030
# 3        1004     30          2428  19014
# 4        1005     32           891  19020

# %%
Prever= NovasVendas_df.iloc[:,1:4].values
NovasVendas_df['Previsao do Modelo ']= Algoritmo_floresta_aleatoria.predict(Prever)

# %%
NovasVendas_df
# Out:
#     Id Cliente  Idade  Preço Seguro    CEP  Previssao do Modelo
# 0         1001     25           801  19001                     1
# 1         1002     27          1090  19027                     1
# 2         1003     45           364  19030                     1
# 3         1004     30          2428  19014                     1
# 4         1005     32           891  19020                     1
# 5         1006     36           823  19025                     1
# 6         1007     44          3895  19032                     3
# 7         1008     36           457  19023                     1
# 8         1009     40           427  19008                     1
# 9         1010     40           928  19009                     1
# 10        1011     45           178  19003                     1
# 11        1012     46          1923  19013                     2
# 12        1013     48          2532  19039                     2
# ...

# %%
NovasVendas_df['Previsao do Modelo '].value_counts()
# Out:
# Previsao do Modelo
# 1    15
# 2     5
# 3     1
# Name: count, dtype: int64
